# %% [markdown]
# ### Conservation status of macrophytes in Austria and Tirol
# ---
# # 1. Build a collection of Macrophytes of Austria

# %%
import yaml
import os
from Bio import Entrez
import polars as pl

from utils import get_taxon_id
from utils import get_taxonlist_species

with open('../config.yml', 'r') as file:
    configs = yaml.safe_load(file)

# %% [markdown]
# As I received a list of Macrophytes (some named by families, some as genera or subgenera), I faced the problem to find all f the corresponding members in the red list of Austria and Tirol.
#
# The red lists can be downloaded here:
# - Northern and eastern Tirol: https://www.uibk.ac.at/de/botany/aktuelles/rote-liste-und-checkliste-der-farn-und-blutenpflanzen-nord-und-osttirols/
# - Austria as a whole: https://www.zobodat.at/publikation_volumes.php?id=69999

# %% [markdown]
# ### Step 1
# Here, we define our files and load the lists into the memory.

# %%
RL_TIR_FILE = "../static/red_list_plants_tirol.csv"  # red list tirol
RL_AUT_FILE = "../static/red_list_plants_austria.csv"  # red list austria
MP_FILE = "../static/macrophytes.txt"  # list of macrophytes

ALLTAXA_OUTFILE = "../static/allmacrophytes_ncbi.txt"  # output file that should contain all macrophyte species that correspond to our list on NCBI
MPSPECIES_TIR_OUTFILE = "../static/macrophytes_species_tirol.txt"  # output file that lists all macrophytes in the red list in tirol
MPSPECIES_AUT_OUTFILE = "../static/macrophytes_species_austria.txt"  # output file that lists all macrophytes in the red list in austria

# %%
red_list_tir_df = pl.read_csv(RL_TIR_FILE)
red_list_aut_df = pl.read_csv(RL_AUT_FILE)

macrophytes = [w.strip() for w in open(MP_FILE, "r").readlines()]

# %% [markdown]
# Hence, we can inspect the list of macrophytes that we should use for the analysis:

# %%
macrophytes
# Out:
# ['Alismataceae',
#  'Hydrocharitaceae',
#  'Nymphaeaceae',
#  'Potamogetonaceae',
#  'Lemnaceae',
#  'Menyanthaceae',
#  'Myriophyllum',
#  'Ceratophyllum',
#  'Callitriche',
#  'Hippuris',
#  'Ranunculus subgen. Batrachium',
#  'Najas',
#  'Utricularia',
#  'Zannichellia',
#  'Typha',
#  'Sparganium']

# %% [markdown]
# ### Step 2
# And so the NCBI taxonomy database can be screened for all species and genera that are included in our selection of macrophyte taxa.

# %%
Entrez.api_key = configs["NCBI_API_KEY"]
Entrez.email = configs["NCBI_EMAIL"]

# %% [markdown]
# This can be done using 2 small functions fetching the NCBI database for all species and genera that belong to a given taxon.

# %%
all_taxa = []
for taxon in macrophytes:
   taxa = get_taxonlist_species(get_taxon_id(taxon))
   for t in taxa : all_taxa.append(t)

# %% [markdown]
# And then we save the data in a predefined file to avoid the need of rerunning.

# %%
sorted(all_taxa)
# Out:
# ['Adelonema',
#  'Adelonema allenii',
#  'Adelonema crinipes',
#  'Adelonema erythropus',
#  'Adelonema hammelii',
#  'Adelonema panamense',
#  'Adelonema peltatum',
#  'Adelonema picturatum',
#  'Adelonema sp. 1 SV-2018',
#  'Adelonema sp. SEL 1992-0029',
#  'Adelonema speariae',
#  'Adelonema wallisii',
#  'Adelonema wendlandii',
#  'Aglaodorum',
#  'Aglaodorum griffithii',
#  'Aglaonema',
#  'Aglaonema cochinchinense',
#  'Aglaonema commutatum',
#  'Aglaonema costatum',
#  'Aglaonema crispum',
#  'Aglaonema hybrid cultivar',
#  'Aglaonema marantifolium',
#  'Aglaonema modestum',
#  'Aglaonema nitidum',
#  'Aglaonema pictum',
#  'Aglaonema rotundum',
#  'Aglaonema simplex',
#  'Aglaonema sp. Carlsen 3112',
#  'Aglaonema sp. DZ-2018',
#  'Aglaonema sp. Red Vein',
#  'Aglaonema tenuipes',
#  'Albidella',
#  'Albidella acanthocarpa',
#  'Albidella nymphaeifolia',
#  'Albidella oligococca',
#  'Alisma',
#  'Alisma canaliculatum',
#  'Alisma gramineum',
#  'Alisma lanceolatum',
#  'Alisma nanum',
#  'Alisma plantago-aquatica',
#  'Alisma rariflorum',
#  'Alisma sp. C-002',
#  'Alisma subcordatum',
#  'Alisma triviale',
#  'Alisma wahlenbergii',
#  'Alloschemone',
#  'Alloschemone inopinata',
#  'Alloschemone occidentalis',
#  'Alocasia',
#  'Alocasia acuminata',
#  'Alocasia alba',
#  'Alocasia argyrea',
#  'Alocasia atropurpurea',
#  'Alocasia beccarii',
#  'Alocasia boa',
#  'Alocasia boyceana',
#  'Alocasia brancifolia',
#  'Alocasia brisbanensis',
#  'Alocasia cf. wongii KR1554',
#  'Alocasia chaii',
#  'Alocasia clypeolata',
#  'Alocasia cucullata',
#  'Alocasia culionensis',
#  'Alocasia cuprea',
#  'Alocasia denudata',
#  'Alocasia fornicata',
#  'Alocasia gageana',
#  'Alocasia grandis',
#  'Alocasia heterophylla',
#  'Alocasia hollrungii',
#  'Alocasia indica',
#  'Alocasia infernalis',
#  'Alocasia inornata',
#  'Alocasia korthalsii',
#  'Alocasia lauterbachiana',
#  'Alocasia longiloba',
#  'Alocasia lowii',
#  'Alocasia macrorrhizos',
#  'Alocasia maquilingensis',
#  'Alocasia melo',
#  'Alocasia micholitziana',
#  'Alocasia monticola',
#  'Alocasia navicularis',
#  'Alocasia nebula',
#  'Alocasia nycteris',
#  'Alocasia odora',
#  'Alocasia pangeran',
#  'Alocasia peltata',
#  'Alocasia perakensis',
#  'Alocasia plumbea',
#  'Alocasia portei',
#  'Alocasia princeps',
#  'Alocasia principiculus',
#  'Alocasia ramosii',
#  'Alocasia reginae',
#  'Alocasia reginula',
#  'Alocasia reversa',
#  'Alocasia ridleyi',
#  'Alocasia robusta',
#  'Alocasia sanderiana',
#  'Alocasia sarawakensis',
#  'Alocasia scabriuscula',
#  'Alocasia scalprum',
#  'Alocasia sinuata',
#  'Alocasia sp. ASPNZ01',
#  'Alocasia sp. Bo011',
#  'Alocasia sp. Bo07',
#  'Alocasia sp. Gomantong',
#  'Alocasia sp. IA-2014',
#  'Alocasia sp. Kerby',
#  'Alocasia sp. MPM1',
#  'Alocasia sp. MPM2',
#  'Alocasia sp. MPM3',
#  'Alocasia sp. MPM4',
#  'Alocasia sp. PSA280',
#  'Alocasia sp. SH-2010',
#  'Alocasia sp. Septier',
#  'Alocasia sp. Setiam',
#  'Alocasia sp. inopinata',
#  'Alocasia sp. kelamensis',
#  'Alocasia sp. kulat',
#  'Alocasia sp. ridleythai',
#  'Alocasia suhirmaniana',
#  'Alocasia warburgii',
#  'Alocasia watsoniana',
#  'Alocasia wongii',
#  'Alocasia zebrina',
#  'Althenia',
#  'Althenia bilocularis',
#  'Althenia cylindrocarpa',
#  'Althenia filiformis',
#  'Althenia hearnii',
#  'Althenia marina',
#  'Althenia orientalis',
#  'Althenia preissii',
#  'Althenia tzvelevii',
#  'Ambrosina',
#  'Ambrosina bassii',
#  'Amorphophallus',
#  'Amorphophallus aberrans',
#  'Amorphophallus abyssinicus',
#  'Amorphophallus albispathus',
#  'Amorphophallus albus',
#  'Amorphophallus amygdaloides',
#  'Amorphophallus andranogidroensis',
#  'Amorphophallus angolensis',
#  'Amorphophallus angulatus',
#  'Amorphophallus angustispathus',
#  'Amorphophallus ankarana',
#  'Amorphophallus antsingyensis',
#  'Amorphophallus aphyllus',
#  'Amorphophallus asterostigmatus',
#  'Amorphophallus atrorubens',
#  'Amorphophallus atroviridis',
#  'Amorphophallus baumannii',
#  'Amorphophallus beccarii',
#  'Amorphophallus bhandarensis',
#  'Amorphophallus bonaccordensis',
#  'Amorphophallus borneensis',
#  'Amorphophallus boyceanus',
#  'Amorphophallus brachyphyllus',
#  'Amorphophallus brevispathus',
#  'Amorphophallus bufo',
#  'Amorphophallus bulbifer',
#  'Amorphophallus calabaricus',
#  'Amorphophallus canaliculatus',
#  'Amorphophallus carneus',
#  'Amorphophallus cicatricifer',
#  'Amorphophallus cirrifer',
#  'Amorphophallus coaetaneus',
#  'Amorphophallus commutatus',
#  'Amorphophallus consimilis',
#  'Amorphophallus corrugatus',
#  'Amorphophallus costatus',
#  'Amorphophallus coudercii',
#  'Amorphophallus croatii',
#  'Amorphophallus cruddasianus',
#  'Amorphophallus curvistylis',
#  'Amorphophallus dactylifer',
#  'Amorphophallus declinatus',
#  'Amorphophallus decus-silvae',
#  'Amorphophallus discophorus',
#  'Amorphophallus dracontioides',
#  'Amorphophallus dunnii',
#  'Amorphophallus dzui',
#  'Amorphophallus eburneus',
#  'Amorphophallus eichleri',
#  'Amorphophallus elatus',
#  'Amorphophallus elegans',
#  'Amorphophallus elliottii',
#  'Amorphophallus erythrorrhachis',
#  'Amorphophallus excentricus',
#  'Amorphophallus fuscus',
#  'Amorphophallus galbra',
#  'Amorphophallus gallowayi',
#  'Amorphophallus gigas',
#  'Amorphophallus glossophyllus',
#  'Amorphophallus gomboczianus',
#  'Amorphophallus haematospadix',
#  'Amorphophallus harmandii',
#  'Amorphophallus henryi',
#  'Amorphophallus hewitii',
#  'Amorphophallus hildebrandtii',
#  'Amorphophallus hirsutus',
#  'Amorphophallus hirtus',
#  'Amorphophallus hohenackeri',
#  'Amorphophallus hottae',
#  'Amorphophallus impressus',
#  'Amorphophallus infundibuliformis',
#  'Amorphophallus interruptus',
#  'Amorphophallus johnsonii',
#  'Amorphophallus josefbogneri',
#  'Amorphophallus julaihii',
#  'Amorphophallus juliae',
#  'Amorphophallus kachinensis',
#  'Amorphophallus kiusianus',
#  'Amorphophallus konjac',
#  'Amorphophallus konkanensis',
#  'Amorphophallus koratensis',
#  'Amorphophallus krausei',
#  'Amorphophallus lacourii',
#  'Amorphophallus lambii',
#  'Amorphophallus lanceolatus',
#  'Amorphophallus lanuginosus',
#  'Amorphophallus laoticus',
#  'Amorphophallus latifolius',
#  'Amorphophallus lewallei',
#  'Amorphophallus linearis',
#  'Amorphophallus longicomus',
#  'Amorphophallus longiconnectivus',
#  'Amorphophallus longituberosus',
#  'Amorphophallus lunatus',
#  'Amorphophallus macrorhizus',
#  'Amorphophallus mangelsdorffii',
#  'Amorphophallus manta',
#  'Amorphophallus margaritifer',
#  'Amorphophallus maximus',
#  'Amorphophallus maxwellii',
#  'Amorphophallus mossambicensis',
#  'Amorphophallus muelleri',
#  'Amorphophallus myosuroides',
#  'Amorphophallus mysorensis',
#  'Amorphophallus napalensis',
#  'Amorphophallus napiger',
#  'Amorphophallus natolii',
#  'Amorphophallus niahensis',
#  'Amorphophallus nicolsonianus',
#  'Amorphophallus obscurus',
#  'Amorphophallus ochroleucus',
#  'Amorphophallus ongsakulii',
#  'Amorphophallus operculatus',
#  'Amorphophallus opertus',
#  'Amorphophallus paeoniifolius',
#  'Amorphophallus palawanensis',
#  'Amorphophallus pendulus',
#  'Amorphophallus perrieri',
#  'Amorphophallus pilosus',
#  'Amorphophallus pingbianensis',
#  'Amorphophallus plicatus',
#  'Amorphophallus polyanthus',
#  'Amorphophallus prainii',
#  'Amorphophallus prolificus',
#  'Amorphophallus pseudoharmandii',
#  'Amorphophallus pulchellus',
#  'Amorphophallus pusillus',
#  'Amorphophallus putii',
#  'Amorphophallus pygmaeus',
#  'Amorphophallus ranchanensis',
#  'Amorphophallus reflexus',
#  'Amorphophallus rhizomatosus',
#  'Amorphophallus rostratus',
#  'Amorphophallus sagittarius',
#  'Amorphophallus salmoneus',
#  'Amorphophallus saraburensis',
#  'Amorphophallus saururus',
#  'Amorphophallus scaber',
#  'Amorphophallus schmidtiae',
#  'Amorphophallus scutatus',
#  'Amorphophallus serrulatus',
#  'Amorphophallus sinuatus',
#  'Amorphophallus sizemoreae',
#  'Amorphophallus smithsonianus',
#  'Amorphophallus sp.',
#  "Amorphophallus sp. 'Makiling'",
#  "Amorphophallus sp. 'kiusiuensis'",
#  'Amorphophallus sp. AM10',
#  'Amorphophallus sp. AM11',
#  'Amorphophallus sp. AM30',
#  'Amorphophallus sp. AM7',
#  'Amorphophallus sp. ARG-24',
#  'Amorphophallus sp. KP-2014',
#  'Amorphophallus sp. MO 6857073',
#  'Amorphophallus sp. YD-2008',
#  'Amorphophallus spectabilis',
#  'Amorphophallus stuhlmannii',
#  'Amorphophallus sumawongii',
#  'Amorphophallus sylvaticus',
#  'Amorphophallus symonianus',
#  'Amorphophallus synandrifer',
#  'Amorphophallus taurostigma',
#  'Amorphophallus tenuispadix',
#  'Amorphophallus tenuistylis',
#  'Amorphophallus terrestris',
#  'Amorphophallus thaiensis',
#  'Amorphophallus tinekeae',
#  'Amorphophallus titanum',
#  'Amorphophallus tonkinensis',
#  'Amorphophallus tuberculatus',
#  'Amorphophallus variabilis',
#  'Amorphophallus verticillatus',
#  'Amorphophallus vogelianus',
#  'Amorphophallus xiei',
#  'Amorphophallus yuloensis',
#  'Amorphophallus yunnanensis',
#  'Amorphophallus zenkeri',
#  'Amydrium',
#  'Amydrium hainanense',
#  'Amydrium humile',
#  'Amydrium magnificum',
#  'Amydrium medium',
#  'Amydrium sp. Carlsen 3544',
#  'Amydrium sp. Croat 101536',
#  'Amydrium sp. Hahn 3295',
#  'Amydrium zippelianum',
#  'Anadendrum',
#  'Anadendrum affine',
#  'Anadendrum marginatum',
#  'Anadendrum microstachyum',
#  'Anadendrum sp. Boyce 1173',
#  'Anadendrum sp. Chase 9985',
#  'Anadendrum sp. LZ-2022a',
#  'Anaphyllopsis',
#  'Anaphyllopsis americana',
#  'Anaphyllum',
#  'Anaphyllum wightii',
#  'Anchomanes',
#  'Anchomanes abbreviatus',
#  'Anchomanes dalzielii',
#  'Anchomanes difformis',
#  'Anchomanes hookeri',
#  'Anthurium',
#  'Anthurium acaule',
#  'Anthurium amnicola',
#  'Anthurium andicola',
#  'Anthurium andraeanum',
#  'Anthurium antioquiense',
#  'Anthurium bakeri',
#  'Anthurium balaoanum',
#  'Anthurium bellum',
#  'Anthurium berriozabalense',
#  'Anthurium besseae',
#  'Anthurium bradeanum',
#  'Anthurium brenesii',
#  'Anthurium brevipedunculatum',
#  'Anthurium bromelicola',
#  'Anthurium brownii',
#  'Anthurium caldasii',
#  'Anthurium caramantae',
#  'Anthurium carchiense',
#  'Anthurium chiapasense',
#  'Anthurium citrifolium',
#  'Anthurium clarinervium',
#  'Anthurium clavigerum',
#  'Anthurium clidemioides',
#  'Anthurium consobrinum',
#  'Anthurium cordatum',
#  'Anthurium cordifolium',
#  'Anthurium coriaceum',
#  'Anthurium crenatum',
#  'Anthurium croatii',
#  'Anthurium crystallinum',
#  'Anthurium cubense',
#  'Anthurium curvispadix',
#  'Anthurium cuspidatum',
#  'Anthurium digitatum',
#  'Anthurium dolichostachyum',
#  'Anthurium dominicense',
#  'Anthurium dressleri',
#  'Anthurium durandii',
#  'Anthurium eminens',
#  'Anthurium flavolineatum',
#  'Anthurium flexile',
#  'Anthurium formosum',
#  'Anthurium fornicifolium',
#  'Anthurium friedrichsthalii',
#  'Anthurium furcatum',
#  'Anthurium giraldoi',
#  'Anthurium gracile',
#  'Anthurium graciliacuminatum',
#  'Anthurium grandifolium',
#  'Anthurium guildingii',
#  'Anthurium halmoorei',
#  'Anthurium harrisii',
#  'Anthurium hoffmannii',
#  'Anthurium hookeri',
#  'Anthurium huixtlense',
#  'Anthurium interruptum',
#  'Anthurium jenmanii',
#  'Anthurium jesusii',
#  'Anthurium kunthii',
#  'Anthurium laciniosum',
#  'Anthurium lancea',
#  'Anthurium lancetillense',
#  'Anthurium lancifolium',
#  'Anthurium leuconeurum',
#  'Anthurium lilacinum',
#  'Anthurium longicaudatum',
#  'Anthurium longipes',
#  'Anthurium longissimum',
#  'Anthurium lucens',
#  'Anthurium lucidum',
#  'Anthurium macarenense',
#  'Anthurium macleanii',
#  'Anthurium maculosum',
#  'Anthurium margaricarpum',
#  'Anthurium michelii',
#  'Anthurium microspadix',
#  'Anthurium mindense',
#  'Anthurium morae',
#  'Anthurium muyunense',
#  'Anthurium napaeum',
#  'Anthurium obtusilobum',
#  'Anthurium obtusum',
#  'Anthurium ochranthum',
#  'Anthurium ovatifolium',
#  'Anthurium oxyphyllum',
#  'Anthurium palenquense',
#  'Anthurium parasiticum',
#  'Anthurium parvispathum',
#  'Anthurium parvum',
#  'Anthurium pedatoradiatum',
#  'Anthurium pedatum',
#  'Anthurium peltigerum',
#  'Anthurium petrophilum',
#  'Anthurium polydactylum',
#  'Anthurium polyschistum',
#  'Anthurium propinquum',
#  'Anthurium protensum',
#  'Anthurium punctatum',
#  'Anthurium radicans',
#  'Anthurium ravenii',
#  'Anthurium recavum',
#  'Anthurium rimbachii',
#  'Anthurium sagittatum',
#  'Anthurium salgarense',
#  'Anthurium scandens',
#  'Anthurium scherzerianum',
#  'Anthurium schottianum',
#  'Anthurium sinuatum',
#  'Anthurium sp. 1 Croat et al. 99678',
#  'Anthurium sp. 2 Croat et al. 99766',
#  'Anthurium sp. LZ-2022a',
#  'Anthurium sp. MHPAA262-08',
#  'Anthurium sp. MHPAA263-08',
#  'Anthurium sp. MHPAA333-08',
#  'Anthurium sp. MHPAA523-08',
#  'Anthurium sp. MHPAA524-08',
#  'Anthurium sp. MHPAA525-08',
#  'Anthurium sp. MHPAA591-08',
#  'Anthurium sp. MHPAA618-08',
#  'Anthurium sp. MHPAA646-08',
#  'Anthurium spathiphyllum',
#  'Anthurium spectabile',
#  'Anthurium subsignatum',
#  'Anthurium thrinax',
#  'Anthurium tremulum',
#  'Anthurium trilobum',
#  'Anthurium uleanum',
#  'Anthurium umbrosum',
#  'Anthurium urbanii',
#  'Anthurium veitchii',
#  'Anthurium venosum',
#  'Anthurium verapazense',
#  'Anthurium vittariifolium',
#  'Anthurium watermaliense',
#  'Anthurium wendlingeri',
#  'Anthurium willdenowii',
#  'Anthurium willifordii',
#  'Anubias',
#  'Anubias afzelii',
#  'Anubias barteri',
#  'Anubias congensis',
#  'Anubias gigantea',
#  'Anubias hastifolia',
#  'Anubias heterophylla',
#  'Apalanthe',
#  'Apoballis',
#  'Apoballis acuminatissima',
#  'Apoballis brevipes',
#  'Apoballis mutata',
#  'Apoballis okadae',
#  'Apoballis ovata',
#  'Apoballis sp. Boyce et al. AR3576',
#  'Apoballis sp. SLL-2016',
#  'Aquarius',
#  'Aquarius macrophyllus',
#  'Aridarum',
#  'Aridarum borneense',
#  'Aridarum burttii',
#  'Aridarum crassum',
#  'Aridarum incavatum',
#  'Aridarum kazuyae',
#  'Aridarum minimum',
#  'Aridarum montanum',
#  'Aridarum orientale',
#  'Aridarum pendek',
#  'Aridarum sp. Jepom ak Tisai AR3973',
#  'Ariopsis',
#  'Ariopsis peltata',
#  'Ariopsis protanthera',
#  'Arisaema',
#  'Arisaema abei',
#  'Arisaema aequinoctiale',
#  'Arisaema aff. pingbianense Murata 23-1',
#  'Arisaema album',
#  'Arisaema amurense',
#  'Arisaema angustatum',
#  'Arisaema aprile',
#  'Arisaema aridum',
#  'Arisaema asperatum',
#  'Arisaema auriculatum',
#  'Arisaema balansae',
#  'Arisaema bannaense',
#  'Arisaema bockii',
#  'Arisaema bonatianum',
#  'Arisaema calcareum',
#  'Arisaema candidissimum',
#  'Arisaema chenii',
#  'Arisaema ciliatum',
#  'Arisaema clavatum',
#  'Arisaema concinnum',
#  'Arisaema consanguineum',
#  'Arisaema cordatum',
#  'Arisaema costatum',
#  'Arisaema cucullatum',
#  'Arisaema dahaiense',
#  'Arisaema decipiens',
#  'Arisaema dracontium',
#  'Arisaema ehimense',
#  'Arisaema elephas',
#  'Arisaema erubescens',
#  'Arisaema exappendiculatum',
#  'Arisaema fargesii',
#  'Arisaema filiforme',
#  'Arisaema fimbriatum',
#  'Arisaema flavum',
#  'Arisaema formosanum',
#  'Arisaema franchetianum',
#  'Arisaema fraternum',
#  'Arisaema galeiforme',
#  'Arisaema garrettii',
#  'Arisaema grapsospadix',
#  'Arisaema griffithii',
#  'Arisaema hainanense',
#  'Arisaema harmandii',
#  'Arisaema hatizyoense',
#  'Arisaema heterocephalum',
#  'Arisaema heterophyllum',
#  'Arisaema hunanense',
#  'Arisaema ilanense',
#  'Arisaema inaense',
#  'Arisaema inclusum',
#  'Arisaema ishizuchiense',
#  'Arisaema iyoanum',
#  'Arisaema jacquemontii',
#  'Arisaema japonicum',
#  'Arisaema jinshajiangense',
#  'Arisaema kawashimae',
#  'Arisaema kerrii',
#  'Arisaema kishidae',
#  'Arisaema kiushianum',
#  'Arisaema kuratae',
#  'Arisaema laminatum',
#  'Arisaema lidaense',
#  'Arisaema lihengianum',
#  'Arisaema limbatum',
#  'Arisaema lobatum',
#  'Arisaema longilaminum',
#  'Arisaema longipedunculatum',
#  'Arisaema macrospathum',
#  'Arisaema maekawae',
#  'Arisaema mairei',
#  'Arisaema matsudae',
#  'Arisaema maximowiczii',
#  'Arisaema maxwellii',
#  'Arisaema mayebarae',
#  'Arisaema microspadix',
#  'Arisaema mildbraedii',
#  'Arisaema minamitanii',
#  'Arisaema minus',
#  'Arisaema monophyllum',
#  'Arisaema muratae',
#  'Arisaema murrayi',
#  'Arisaema nagiense',
#  'Arisaema nambae',
#  'Arisaema negishii',
#  'Arisaema nepenthoides',
#  'Arisaema nikoense',
#  'Arisaema ogatae',
#  'Arisaema omkoiense',
#  'Arisaema ostiolatum',
#  'Arisaema ovale',
#  'Arisaema pangii',
#  'Arisaema penicillatum',
#  'Arisaema peninsulae',
#  'Arisaema petelotii',
#  'Arisaema planilaminum',
#  'Arisaema polyphyllum',
#  'Arisaema prazeri',
#  'Arisaema propinquum',
#  'Arisaema pseudoangustatum',
#  'Arisaema quinquelobatum',
#  'Arisaema rhizomatum',
#  'Arisaema ringens',
#  'Arisaema robustum',
#  'Arisaema roxburghii',
#  'Arisaema rubrirhizomatum',
#  'Arisaema sachalinense',
#  'Arisaema sahyadricum',
#  'Arisaema saxatile',
#  'Arisaema sazensoo',
#  'Arisaema schimperianum',
#  'Arisaema scortechinii',
#  'Arisaema seppikoense',
#  'Arisaema serratum',
#  'Arisaema shimienense',
#  'Arisaema sikokianum',
#  'Arisaema sinii',
#  'Arisaema solenochlamys',
#  'Arisaema sp. 030869',
#  'Arisaema sp. Barabe 150',
#  'Arisaema sp. He s.n.',
#  'Arisaema sp. KH-2014',
#  'Arisaema sp. KH-2015',
#  'Arisaema sp. MD',
#  'Arisaema sp. Muramatsu 27229',
#  'Arisaema sp. Murata 2310',
#  'Arisaema sp. Nie and Meng 435',
#  'Arisaema sp. VN25',
#  'Arisaema speciosum',
#  'Arisaema suwoense',
#  'Arisaema taiwanense',
#  'Arisaema takedae',
#  'Arisaema takesimense',
#  'Arisaema tashiroi',
#  'Arisaema ternatipartitum',
#  'Arisaema thunbergii',
#  'Arisaema tortuosum',
#  'Arisaema tosaense',
#  'Arisaema triphyllum',
#  'Arisaema umbrinum',
#  'Arisaema undulatifolium',
#  'Arisaema unzenense',
#  'Arisaema utile',
#  'Arisaema wattii',
#  'Arisaema wilsonii',
#  'Arisaema wrayi',
#  'Arisaema yamatense',
#  'Arisaema yunnanense',
#  'Arisarum',
#  'Arisarum proboscideum',
#  'Arisarum simorrhinum',
#  'Arisarum vulgare',
#  'Arophyton',
#  'Arophyton buchetii',
#  'Arum',
#  'Arum alpinum',
#  'Arum apulum',
#  'Arum balansanum',
#  'Arum besserianum',
#  'Arum byzantinum',
#  'Arum concinnatum',
#  'Arum creticum',
#  'Arum cylindraceum',
#  'Arum cyrenaicum',
#  'Arum dioscoridis',
#  'Arum elongatum',
#  'Arum euxinum',
#  'Arum gratum',
#  'Arum hygrophilum',
#  'Arum idaeum',
#  'Arum italicum',
#  'Arum jacquemontii',
#  'Arum korolkowii',
#  'Arum lucanum',
#  'Arum maculatum',
#  'Arum megobrebi',
#  'Arum nigrum',
#  'Arum orientale',
#  'Arum palaestinum',
#  'Arum pictum',
#  'Arum purpureospathum',
#  'Arum rupicola',
#  'Arum sintenisii',
#  'Arum sp. Lobin 26940',
#  'Asterostigma',
#  'Asterostigma cryptostylum',
#  'Asterostigma cubense',
#  'Asterostigma lividum',
#  'Asterostigma lombardii',
#  'Asterostigma reticulatum',
#  'Asterostigma riedelianum',
#  'Asterostigma tweedianum',
#  'Astonia',
#  'Astonia australiensis',
#  'Bakoa',
#  'Bakoa lucens',
#  'Bakoaella',
#  'Bakoaella nakamotoi',
#  'Bakoaella sicula',
#  'Baldellia',
#  'Baldellia alpestris',
#  'Baldellia ranunculoides',
#  'Baldellia repens',
#  'Barclaya',
#  'Barclaya hirta',
#  'Barclaya kunstleri',
#  'Barclaya longifolia',
#  'Barclaya motleyi',
#  'Barclaya panchorensis',
#  'Barclaya rotundifolia',
#  'Barclaya rugosa',
#  'Barclaya wellyi',
#  'Biarum',
#  'Biarum arundanum',
#  'Biarum bovei',
#  'Biarum carduchorum',
#  'Biarum davisii',
#  'Biarum dispar',
#  'Biarum ditschianum',
#  'Biarum kotschyi',
#  'Biarum pyrami',
#  'Biarum straussii',
#  'Biarum tenuifolium',
#  'Blyxa',
#  'Blyxa aubertii',
#  'Blyxa echinosperma',
#  'Blyxa japonica',
#  'Bognera',
#  'Bognera recondita',
#  'Bucephalandra',
#  'Bucephalandra akantha',
#  'Bucephalandra bogneri',
#  'Bucephalandra catherineae',
#  'Bucephalandra kishii',
#  'Bucephalandra motleyana',
#  'Bucephalandra pygmaea',
#  'Bucephalandra sp. SLL-2016',
#  'Burnatia',
#  'Burnatia enneandra',
#  'Burttianthus',
#  'Burttianthus caulescens',
#  'Burttianthus orestus',
#  'Burttianthus purseglovei',
#  'Burttianthus spissus',
#  'Burttianthus veluntandrus',
#  'Butomopsis',
#  'Butomopsis latifolia',
#  'Caladium',
#  'Caladium bicolor',
#  'Caladium humboldtii',
#  'Caladium hybrid cultivar',
#  'Caladium lindenii',
#  'Caladium picturatum',
#  'Caladium praetermissum',
#  'Caldesia',
#  'Caldesia grandis',
#  'Caldesia parnassifolia',
#  'Calla',
#  'Calla palustris',
#  'Callitriche',
#  'Callitriche albomarginata',
#  'Callitriche anceps',
#  'Callitriche antarctica',
#  'Callitriche brutia',
#  'Callitriche cf. heterophylla JP-2019',
#  'Callitriche cf. heterophylla JP-2020',
#  'Callitriche cf. stagnalis JP-2019',
#  'Callitriche cf. stagnalis JP-2020',
#  'Callitriche compressa',
#  'Callitriche cophocarpa',
#  'Callitriche cribrosa',
#  'Callitriche deflexa',
#  'Callitriche fehmedianii',
#  'Callitriche fimbriata',
#  'Callitriche hamulata',
#  'Callitriche hermaphroditica',
#  'Callitriche heterophylla',
#  'Callitriche heteropoda',
#  'Callitriche japonica',
#  'Callitriche lechleri',
#  'Callitriche lenisulca',
#  'Callitriche lusitanica',
#  'Callitriche marginata',
#  'Callitriche muelleri',
#  'Callitriche nana',
#  'Callitriche nuttallii',
#  'Callitriche obtusangula',
#  'Callitriche occidentalis',
#  'Callitriche palustris',
#  'Callitriche peploides',
#  'Callitriche petriei',
#  'Callitriche platycarpa',
#  'Callitriche pulchra',
#  'Callitriche regis-jubae',
#  'Callitriche sonderi',
#  'Callitriche sp. Albach 491',
#  'Callitriche stagnalis',
#  "Callitriche stagnalis 'autotriploid'",
#  'Callitriche terrestris',
#  'Callitriche transvolgensis',
#  'Callitriche trochlearis',
#  'Callitriche truncata',
#  'Callitriche umbonata',
#  'Callopsis',
#  'Callopsis volkensii',
#  'Carlephyton',
#  'Carlephyton glaucophyllum',
#  'Ceratophyllum',
#  'Ceratophyllum demersum',
#  'Ceratophyllum echinatum',
#  'Ceratophyllum muricatum',
#  'Ceratophyllum platyacanthum',
#  'Ceratophyllum sp. SM-2010',
#  'Ceratophyllum sp. US:3560551',
#  'Ceratophyllum submersum',
#  'Ceratophyllum tanaiticum',
#  'Cercestis',
#  'Cercestis afzelii',
#  'Cercestis camerunensis',
#  'Cercestis kamerunianus',
#  'Cercestis mirabilis',
#  'Cercestis sp. LLO-2016',
#  'Cercestis stigmaticus',
#  'Chlorospatha',
#  'Chlorospatha atropurpurea',
#  'Chlorospatha longipoda',
#  'Chlorospatha sp. Chase 11912',
#  'Colletogyne',
#  'Colletogyne perrieri',
#  'Colocasia',
#  'Colocasia affinis',
#  'Colocasia esculenta',
#  'Colocasia fallax',
#  'Colocasia formosana',
#  'Colocasia heterochroma',
#  'Colocasia lihengiae',
#  'Colocasia menglaensis',
#  'Colocasia sp. (in: monocots)',
#  'Colocasia sp. Boyce s.n.',
#  'Colocasia sp. IA-2014',
#  'Colocasia sp. MIB:SASS:0433',
#  'Colocasia tonoimo',
#  'Colocasia yunnanensis',
#  'Croatiella',
#  'Croatiella integrifolia',
#  'Cryptocoryne',
#  'Cryptocoryne affinis',
#  'Cryptocoryne auriculata',
#  'Cryptocoryne bangkaensis',
#  'Cryptocoryne bastmeijeri',
#  'Cryptocoryne bullosa',
#  'Cryptocoryne ciliata',
#  'Cryptocoryne cordata',
#  'Cryptocoryne crispatula',
#  'Cryptocoryne decus-silvae',
#  'Cryptocoryne edithiae',
#  'Cryptocoryne elliptica',
#  'Cryptocoryne ferruginea',
#  'Cryptocoryne fusca',
#  'Cryptocoryne griffithii',
#  'Cryptocoryne hudoroi',
#  'Cryptocoryne ideii',
#  'Cryptocoryne jacobsenii',
#  'Cryptocoryne keei',
#  'Cryptocoryne lingua',
#  'Cryptocoryne longicauda',
#  'Cryptocoryne matakensis',
#  'Cryptocoryne minima',
#  'Cryptocoryne nurii',
#  'Cryptocoryne pallidinervia',
#  'Cryptocoryne schulzei',
#  'Cryptocoryne scurrilis',
#  'Cryptocoryne sinensis',
#  'Cryptocoryne sp. CyCy605',
#  'Cryptocoryne sp. CyCy605Type1',
#  'Cryptocoryne sp. CyCy605Type2',
#  'Cryptocoryne sp. CyCy605Type3',
#  'Cryptocoryne sp. CyCy605Type4',
#  'Cryptocoryne sp. CyCy605Type5',
#  'Cryptocoryne sp. CyCy802',
#  'Cryptocoryne sp. CyCy802Type1',
#  'Cryptocoryne sp. CyCy802Type2',
#  'Cryptocoryne sp. CyCy802Type3',
#  'Cryptocoryne sp. CyCy802Type4',
#  'Cryptocoryne sp. CyCy802Type5',
#  'Cryptocoryne sp. CyCy802Type6',
#  'Cryptocoryne sp. CyCy802Type7',
#  'Cryptocoryne sp. CyCy802Type8',
#  'Cryptocoryne sp. FL09-16',
#  'Cryptocoryne spiralis',
#  'Cryptocoryne striolata',
#  'Cryptocoryne uenoi',
#  'Cryptocoryne villosa',
#  'Cryptocoryne wongsoi',
#  'Cryptocoryne yujii',
#  'Cryptocoryne zaidiana',
#  'Culcasia',
#  'Culcasia angolensis',
#  'Culcasia falcifolia',
#  'Culcasia liberica',
#  'Culcasia mannii',
#  'Culcasia parviflora',
#  'Culcasia rotundifolia',
#  'Culcasia saxatilis',
#  'Culcasia striolata',
#  'Cyrtosperma',
#  'Cyrtosperma carrii',
#  'Cyrtosperma cuspidispathum',
#  'Cyrtosperma macrotum',
#  'Cyrtosperma merkusii',
#  'Damasonium',
#  'Damasonium alisma',
#  'Damasonium californicum',
#  'Damasonium minus',
#  'Damasonium polyspermum',
#  'Dieffenbachia',
#  'Dieffenbachia aglaonematifolia',
#  'Dieffenbachia elegans',
#  'Dieffenbachia humilis',
#  'Dieffenbachia oerstedii',
#  'Dieffenbachia parlatorei',
#  'Dieffenbachia pittieri',
#  'Dieffenbachia seguine',
#  'Dieffenbachia sp. A.Guadamuz',
#  'Dieffenbachia sp. Goncalves 164',
#  'Dieffenbachia sp. KRJ-2009',
#  'Dieffenbachia sp. Qiu 96007',
#  'Dieffenbachia spruceana',
#  'Dieffenbachia tonduzii',
#  'Dracontioides',
#  'Dracontioides desciscens',
#  'Dracontium',
#  'Dracontium asperum',
#  'Dracontium dressleri',
#  'Dracontium gigas',
#  'Dracontium polyphyllum',
#  'Dracontium sp. Mason s.n.',
#  'Dracunculus',
#  'Dracunculus canariensis',
#  'Dracunculus vulgaris',
#  'Echinodorus',
#  'Echinodorus africanus',
#  'Echinodorus amazonicus',
#  'Echinodorus barthii',
#  'Echinodorus berteroi',
#  'Echinodorus bracteatus',
#  'Echinodorus cf. opacus SL-2011',
#  'Echinodorus cf. osiris E80',
#  'Echinodorus cf. osiris SL-2011',
#  'Echinodorus cordifolius',
#  'Echinodorus decumbens',
#  'Echinodorus emersus',
#  'Echinodorus floribundus',
#  'Echinodorus floridanus',
#  'Echinodorus gabrielii',
#  'Echinodorus glaucus',
#  'Echinodorus grandiflorus',
#  'Echinodorus grisebachii',
#  'Echinodorus heikobleheri',
#  'Echinodorus horemanii',
#  'Echinodorus horizontalis',
#  'Echinodorus hybrid cultivar',
#  'Echinodorus inpai',
#  'Echinodorus longipetalus',
#  'Echinodorus longiscapus',
#  'Echinodorus maculatus',
#  'Echinodorus major',
#  'Echinodorus muricatus',
#  'Echinodorus opacus',
#  'Echinodorus osiris',
#  'Echinodorus palifolius',
#  'Echinodorus paniculatus',
#  'Echinodorus portoalegrensis',
#  'Echinodorus pseudohorizontalis',
#  'Echinodorus pubescens',
#  'Echinodorus reptilis',
#  'Echinodorus scaber',
#  'Echinodorus schlueteri',
#  'Echinodorus sp. 1 LYC-2011',
#  'Echinodorus sp. 2 LYC-2011',
#  'Echinodorus sp. 3 LYC-2011',
#  'Echinodorus sp. 3 SL-2011',
#  'Echinodorus sp. 4 SL-2011',
#  'Echinodorus subalatus',
#  'Echinodorus trialatus',
#  'Echinodorus tunicatus',
#  'Echinodorus uruguayensis',
#  'Echinodorus viridis',
#  ...]

# %% [markdown]
# One can already see, there are somehow a lot of members of Araceae included. Somehow this must be a problem with the structure of the taxonomic tree on NCBI - Maybe with Alismataceae or Lemnaceae? We do not go into detail but will need some manual curation of the results.
#
# But first, we save the file.

# %%
#with open(ALLTAXA_OUTFILE, "w") as fl:
#    [fl.write(f"{t}\n") for t in all_taxa]

# %% [markdown]
# ### Step 3
# Next, we go through each of those species and genera with and select those in our red lsits, that correspond to them.

# %%
# for the red list of tirol:
with open(MPSPECIES_TIR_OUTFILE, "w") as fl:
    for tx in red_list_tir_df["Taxon"]:
        if tx in all_taxa or any([tx.startswith(f"{t} ") for t in all_taxa]):
            fl.write(f"{tx}\n")

# %%
# for the red list of Austria:
with open(MPSPECIES_AUT_OUTFILE, "w") as fl:
    for tx in red_list_aut_df["Taxon"]:
        try:
            if tx in all_taxa or any([tx.startswith(f"{t} ") for t in all_taxa]):
                if not "→" in tx: fl.write(f"{tx}\n")

        except AttributeError:
            continue

# %% [markdown]
# So the preselection of macrophyte species in tirol are these:

# %%
with open(MPSPECIES_TIR_OUTFILE, "r") as file:
    print(file.read())
# Out:
# Alisma lanceolatum
# Alisma plantago-aquatica s. str.
# Arum maculatum s. str.
# Calla palustris
# Callitriche cophocarpa
# Callitriche hamulata
# Callitriche obtusangula
# Callitriche palustris s. str.
# Callitriche platycarpa
# Ceratophyllum demersum
# Elodea canadensis
# Elodea nuttallii
# Groenlandia densa
# Hippuris vulgaris
# Hydrocharis morsus-ranae
# Lemna minor
# Lemna trisulca
# Lysichiton americanus
# Menyanthes trifoliata
# Myriophyllum spicatum
# Myriophyllum verticillatum
# Najas marina s. str.
# Najas minor
# Nuphar lutea
# Nuphar pumila
# Nymphaea alba
# Nymphaea candida
# Nymphoides peltata
# Potamogeton alpinus
# Potamogeton × angustifolius
# Potamogeton berchtoldii
# Potamogeton crispus
# Potamogeton gramineus
# Potamogeton lucens
# Potamogeton natans
# Potamogeton × nitens
# Potamogeton nodosus
# Potamogeton perfoliatus
# Potamogeton praelongus
# Potamogeton pusillus s. str.
# Potamogeton trichoides
# Sagittaria latifolia
# Sagittaria sagittifolia
# Sparganium angustifolium
# Sparganium emersum
# Sparganium erectum subsp. erectum
# Sparganium erectum subsp. microcarpum
# Sparganium erectum subsp. neglectum
# Sparganium natans
# Spirodela polyrhiza
# Stratiotes aloides
# Stuckenia filiformis
# Stuckenia pectinata
# Typha angustifolia
# Typha latifolia
# Typha minima s. str.
# Typha shuttleworthii
# Utricularia australis
# Utricularia intermedia s. str.
# Utricularia minor s. str.
# Utricularia stygia
# Utricularia vulgaris s. str.
# Zannichellia palustris

# %% [markdown]
# For Austria it is those:

# %%
with open(MPSPECIES_AUT_OUTFILE, "r") as file:
    print(file.read())
# Out:
# Alisma gramineum
# Alisma lanceolatum
# Alisma plantago-aquatica s.str.
# Arum cylindraceum
# Arum italicum
# Arum maculatum s.str.
# Caldesia parnassifolia
# Calla palustris
# Callitriche cophocarpa
# Callitriche hamulata
# Callitriche obtusangula
# Callitriche palustris s.str.
# Callitriche platycarpa
# Callitriche stagnalis
# Ceratophyllum demersum
# Ceratophyllum submersum
# Cryptocoryne balansae
# Cryptocoryne wendtii
# Elodea canadensis
# Elodea nuttallii
# Groenlandia densa
# Hippuris vulgaris
# Hydrocharis morsus-ranae
# Lemna gibba
# Lemna minor
# Lemna minuta
# Lemna trisulca
# Lemna turionifera
# Menyanthes trifoliata
# Myriophyllum alterniflorum
# Myriophyllum aquaticum
# Myriophyllum heterophyllum
# Myriophyllum spicatum
# Myriophyllum verticillatum
# Najas flexilis
# Najas marina agg.
# Najas major
# Najas marina s.str.
# Najas minor
# Nuphar advena
# Nuphar lutea
# Nuphar pumila
# Nymphaea alba
# Nymphaea candida
# Nymphoides peltata
# Potamogeton acutifolius
# Potamogeton alpinus
# Potamogeton berchtoldii
# Potamogeton coloratus
# Potamogeton compressus
# Potamogeton crispus
# Potamogeton friesii
# Potamogeton gramineus
# Potamogeton lucens
# Potamogeton natans
# Potamogeton nodosus
# Potamogeton obtusifolius
# Potamogeton perfoliatus
# Potamogeton polygonifolius
# Potamogeton praelongus
# Potamogeton pusillus s.str.
# Potamogeton trichoides
# Sagittaria sagittifolia
# Sparganium angustifolium
# Sparganium emersum
# Sparganium erectum
# Sparganium erectum subsp. erectum
# Sparganium erectum subsp.  microcarpum
# Sparganium erectum subsp. neglectum
# Sparganium erectum subsp. oocarpum
# Sparganium natans
# Spirodela polyrhiza
# Stratiotes aloides
# Stuckenia filiformis
# Stuckenia pectinata
# Typha angustifolia
# Typha latifolia
# Typha laxmannii
# Typha minima
# Typha shuttleworthii
# Utricularia australis
# Utricularia bremii
# Utricularia intermedia agg.
# Utricularia intermedia s.str.
# Utricularia ochroleuca
# Utricularia stygia
# Utricularia minor s.str.
# Utricularia vulgaris s.str.
# Vallisneria spiralis
# Wolffia arrhiza
# Zannichellia palustris subsp. palustris
# Zannichellia palustris subsp. pedicellata

# %% [markdown]
# Again, we observe that some Araceae are included. Also, we are missing the *Ranunculus* subg. *Batrachium* taxa. Hence, we will do some manual curation of the selection.

# %% [markdown]
# ### Step 4

# %% [markdown]
# So for the final lists some manual curation will be performed. The Araceae in the lists are removed and all members of *Ranunculus* subg. *Batrachium* added.

# %%
MPSPECIES_FIN_TIR_OUTFILE = "../static/macrophytes_species_final_tirol.txt"  # manually curated output file that lists all macrophytes in the red list in tirol
MPSPECIES_FIN_AUT_OUTFILE = "../static/macrophytes_species_final_austria.txt"  # manually curated output file that lists all macrophytes in the red list in austria

# %% [markdown]
# Hence, here we present the taxa of the study:
#
#
# - For Tirol, we will analyze:

# %%
with open(MPSPECIES_FIN_TIR_OUTFILE, "r") as file:
    print(file.read())
# Out:
# Alisma lanceolatum
# Alisma plantago-aquatica s. str.
# Callitriche cophocarpa
# Callitriche hamulata
# Callitriche obtusangula
# Callitriche palustris s. str.
# Callitriche platycarpa
# Ceratophyllum demersum
# Elodea canadensis
# Elodea nuttallii
# Groenlandia densa
# Hippuris vulgaris
# Hydrocharis morsus-ranae
# Lemna minor
# Lemna trisulca
# Menyanthes trifoliata
# Myriophyllum spicatum
# Myriophyllum verticillatum
# Najas marina s. str.
# Najas minor
# Nuphar lutea
# Nuphar pumila
# Nymphaea alba
# Nymphaea candida
# Nymphoides peltata
# Potamogeton alpinus
# Potamogeton berchtoldii
# Potamogeton crispus
# Potamogeton gramineus
# Potamogeton lucens
# Potamogeton natans
# Potamogeton nodosus
# Potamogeton perfoliatus
# Potamogeton praelongus
# Potamogeton pusillus s. str.
# Potamogeton trichoides
# Potamogeton × angustifolius
# Potamogeton × nitens
# Ranunculus aquatilis
# Ranunculus circinatus
# Ranunculus confervoides
# Ranunculus penicillatus s. str.
# Ranunculus rionii
# Ranunculus sceleratus
# Ranunculus trichophyllus
# Sagittaria latifolia
# Sagittaria sagittifolia
# Sparganium angustifolium
# Sparganium emersum
# Sparganium erectum subsp. erectum
# Sparganium erectum subsp. microcarpum
# Sparganium erectum subsp. neglectum
# Sparganium natans
# Spirodela polyrhiza
# Stratiotes aloides
# Stuckenia filiformis
# Stuckenia pectinata
# Typha angustifolia
# Typha latifolia
# Typha minima s. str.
# Typha shuttleworthii
# Utricularia australis
# Utricularia intermedia s. str.
# Utricularia minor s. str.
# Utricularia stygia
# Utricularia vulgaris s. str.
# Zannichellia palustris

# %% [markdown]
# - For Austria it is:

# %%
with open(MPSPECIES_FIN_AUT_OUTFILE, "r") as file:
    print(file.read())
# Out:
# Alisma gramineum
# Alisma lanceolatum
# Alisma plantago-aquatica s.str.
# Caldesia parnassifolia
# Callitriche cophocarpa
# Callitriche hamulata
# Callitriche obtusangula
# Callitriche palustris s.str.
# Callitriche platycarpa
# Callitriche stagnalis
# Ceratophyllum demersum
# Ceratophyllum submersum
# Elodea canadensis
# Elodea nuttallii
# Groenlandia densa
# Hippuris vulgaris
# Hydrocharis morsus-ranae
# Lemna gibba
# Lemna minor
# Lemna minuta
# Lemna trisulca
# Lemna turionifera
# Menyanthes trifoliata
# Myriophyllum alterniflorum
# Myriophyllum aquaticum
# Myriophyllum heterophyllum
# Myriophyllum spicatum
# Myriophyllum verticillatum
# Najas flexilis
# Najas major
# Najas marina agg.
# Najas marina s.str.
# Najas minor
# Nuphar advena
# Nuphar lutea
# Nuphar pumila
# Nymphaea alba
# Nymphaea candida
# Nymphoides peltata
# Potamogeton acutifolius
# Potamogeton alpinus
# Potamogeton berchtoldii
# Potamogeton coloratus
# Potamogeton compressus
# Potamogeton crispus
# Potamogeton friesii
# Potamogeton gramineus
# Potamogeton lucens
# Potamogeton natans
# Potamogeton nodosus
# Potamogeton obtusifolius
# Potamogeton perfoliatus
# Potamogeton polygonifolius
# Potamogeton praelongus
# Potamogeton pusillus s.str.
# Potamogeton trichoides
# Ranunculus aquatilis s.str.
# Ranunculus baudotii
# Ranunculus circinatus
# Ranunculus confervoides
# Ranunculus fluitans
# Ranunculus peltatus
# Ranunculus penicillatus s.str.
# Ranunculus pseudofluitans
# Ranunculus rionii
# Ranunculus sceleratus
# Ranunculus trichophyllus s.strictiore
# Sagittaria sagittifolia
# Sparganium angustifolium
# Sparganium emersum
# Sparganium erectum
# Sparganium erectum subsp.  microcarpum
# Sparganium erectum subsp. erectum
# Sparganium erectum subsp. neglectum
# Sparganium erectum subsp. oocarpum
# Sparganium natans
# Spirodela polyrhiza
# Stratiotes aloides
# Stuckenia filiformis
# Stuckenia pectinata
# Typha angustifolia
# Typha latifolia
# Typha laxmannii
# Typha minima
# Typha shuttleworthii
# Utricularia australis
# Utricularia bremii
# Utricularia intermedia agg.
# Utricularia intermedia s.str.
# Utricularia minor s.str.
# Utricularia ochroleuca
# Utricularia stygia
# Utricularia vulgaris s.str.
# Vallisneria spiralis
# Wolffia arrhiza
# Zannichellia palustris subsp. palustris
# Zannichellia palustris subsp. pedicellata

# %% [markdown]
# With this selection we can continue in the next Notebook with some statistics.
